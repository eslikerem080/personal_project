# %%
import pandas as pd
import import_ipynb
from Neo4j import *
import matplotlib.pyplot as plt
from graph_analyser import *
from etherscan_scrapper_v0 import *
# Out:
# importing Jupyter notebook from graph_analyser.ipynb

# %%
conn = Neo4jConnection(uri="bolt://localhost:7687", 
                       user="neo4j",              
                       pwd="usdt")

# %%
dai_analyser = graph_analyser(conn, 'USDT')
# Out:
# USDT

# %%
def assign_name(original_name, new_name, dictionary, iteration):
    if new_name in dictionary:
        iteration += 1
        return assign_name(original_name, original_name + " " + str(iteration), dictionary, iteration)
    return new_name

# %%
def rank_named_addresses(address_score, centralityType, analyser):
    
    number_of_top_addresses = 30
    address_owners = {}
    url_start = "https://etherscan.io/address/"
    for index, row in address_score.head(number_of_top_addresses).iterrows():
        address = row["address"]
        parser = etherscanParser("https://etherscan.io/address/" + address)
        address_owners[address] = {}
        address_owners[address]['href'] = parser.get_labels_through_href() 
        address_owners[address]['title'] = parser.get_public_address_tag() 
        
    # cleaning address owner data
    clean_owners = {}
    count_unknown = 0
    for address in address_owners:

        if(str(analyser.get_node_name(address)[0]) == "None"):
            if "Address" not in address_owners[address]['title'] and 'Ethereum Accoun' not in address_owners[address]['title'] and address_owners[address]['href'] != '' and 'Ethereum BlockChain Explorer' not in address_owners[address]['title']:
                clean_owners[address] = address_owners[address]['title'] + " " + address_owners[address]['href']
            elif "Address" not in address_owners[address]['title'] and 'Ethereum Accoun' not in address_owners[address]['title'] and 'Ethereum BlockChain Explorer' not in address_owners[address]['title']:
                clean_owners[address] = address_owners[address]['title']
            elif address_owners[address]['href'] != '':
                clean_owners[address] = address_owners[address]['href']
            else:
                clean_owners[address] = "Unknown" + str(count_unknown)
                count_unknown += 1
    
        else:
            print(address)
            clean_owners[address] = str(analyser.get_node_name(address)[0])
            
            
    top_scores = {}
    pr_centrality_scores= address_score.set_index('address')[centralityType].to_dict()

    for address in clean_owners.keys():
        name = assign_name(clean_owners[address], clean_owners[address], top_scores, 0)
        top_scores[name] = pr_centrality_scores[address]

    top_scorers_df = pd.DataFrame.from_dict(data = top_scores, columns = [centralityType], orient='index')
    top_scorers_df.plot.bar()

# %%
dai_analyser.calculate_pageRank_centrality_for_all_nodes()

# %%
rank_named_addresses(dai_analyser.pageRank_centrality_score_by_node, "pageRankCentrality", dai_analyser)

# %%
dai_analyser.calculate_eigen_centrality_for_all_nodes()

# %%
rank_named_addresses(dai_analyser.eigen_centrality_score_by_node, "eigenCentrality", dai_analyser)

# %%
dai_analyser.calculate_betweeness_centrality_for_all_nodes()

# %%
rank_named_addresses(dai_analyser.betweenness_centrality_score_by_node, "betweennessCentrality", dai_analyser)

# %%
# get owners for addresse with top score
number_of_top_addresses = 200
address_owners = {}
url_start = "https://etherscan.io/address/"
for index, row in dai_analyser.pageRank_centrality_score_by_node.head(number_of_top_addresses).iterrows():
    address = row["address"]
    parser = etherscanParser("https://etherscan.io/address/" + address)
    address_owners[address] = {}
    address_owners[address]['href'] = parser.get_labels_through_href() 
    address_owners[address]['title'] = parser.get_address_name()

# %%
# cleaning address owner data
clean_owners = {}
for address in address_owners:
    if "Address" not in address_owners[address]['title'] and 'Ethereum Accoun' not in address_owners[address]['title'] and address_owners[address]['href'] != '':
        clean_owners[address] = address_owners[address]['title'] + " " + address_owners[address]['href']
    elif "Address" not in address_owners[address]['title'] and 'Ethereum Accoun' not in address_owners[address]['title']:
        clean_owners[address] = address_owners[address]['title']
    elif address_owners[address]['href'] != '':
        clean_owners[address] = address_owners[address]['href']
    else:
        clean_owners[address] = "unknown"

# %%
count = 0
top_scores = {}
pr_centrality_scores= dai_analyser.pageRank_centrality_score_by_node.set_index('address')['pageRankCentrality'].to_dict()


for address in clean_owners.keys():
    if(clean_owners[address] != "unknown" and clean_owners[address]!= "Ethereum BlockChain Explorer"):
        top_scores[clean_owners[address]] = pr_centrality_scores[address]

top_scorers_df = pd.DataFrame.from_dict(data = top_scores, columns = ["PageRank Score"], orient='index')
top_scorers_df.plot.bar()

# %%
def clean_address_owners(address_owners):
    clean_owners = {}
    for address in address_owners:
        if "Address" not in address_owners[address]['title'] and 'Ethereum Accoun' not in address_owners[address]['title'] and address_owners[address]['href'] != '':
            clean_owners[address] = address_owners[address]['title'] + " " + address_owners[address]['href']
        elif "Address" not in address_owners[address]['title'] and 'Ethereum Accoun' not in address_owners[address]['title']:
            clean_owners[address] = address_owners[address]['title']
        elif address_owners[address]['href'] != '':
            clean_owners[address] = address_owners[address]['href']
        else:
            clean_owners[address] = "unknown"
            
    return clean_owners

# %%
unweighted_address_owners = {'0x28c6c06298d514db089934071355e5743bf21d60': {'href': 'binance exchange ', 'title': 'Address 0x28c6c06298d514db089934071355e5743bf21d60'}, '0x34d7d7aaf50ad4944b70b320acb24c95fa2def7c': {'href': 'sushiswap ', 'title': 'SushiSwap OHMDAI 2'}, '0x503828976d22510aad0201ac7ec88293211d23da': {'href': 'coinbase ', 'title': 'Address 0x503828976d22510aad0201ac7ec88293211d23da'}, '0x74de5d4fcbf63e00296fd95d33236b9794016631': {'href': '', 'title': 'Contract Address 0x74de5d4fcbf63e00296fd95d33236b9794016631'}, '0xa478c2975ab1ea89e8196811f51a7b7ade33eb11': {'href': 'uniswap ', 'title': 'Uniswap V2 DAI 2'}, '0xfd3dfb524b2da40c8a6d703c62be36b5d8540626': {'href': '', 'title': 'Contract Address 0xfd3dfb524b2da40c8a6d703c62be36b5d8540626'}, '0x06da0fd433c1a5d7a4faa01111c044910a184553': {'href': 'sushiswap ', 'title': 'SushiSwap USDT'}, '0x0000000000000000000000000000000000000000': {'href': 'blocked ', 'title': 'Address 0x0000000000000000000000000000000000000000'}, '0xc3d03e4f041fd4cd388c549ee2a29a9e5075882f': {'href': 'sushiswap ', 'title': 'SushiSwap DAI'}, '0x0000006daea1723962647b7e189d311d757fb793': {'href': '', 'title': 'Wintermute'}, '0xa5d07e978398eb1715056d3ca5cb31035c02fdad': {'href': '', 'title': 'Address 0xa5d07e978398eb1715056d3ca5cb31035c02fdad'}, '0x2a549b4af9ec39b03142da6dc32221fc390b5533': {'href': 'blockfi ', 'title': 'BlockFi 3'}, '0x0c9d28f3d6a076484a357ad75a6a3b4df71c3f87': {'href': '', 'title': 'Contract Address 0x0c9d28f3d6a076484a357ad75a6a3b4df71c3f87'}, '0xd1a1a62a01db5d40f7de05142c29ed74dacb0779': {'href': '', 'title': 'Contract Address 0xd1a1a
href': '', 'title': 'Ethereum Accoun'}, '0x498e9f240158c11e822c983938d1a093a81e0e3c': {'href': '', 'title': 'Ethereum Accoun'}, '0xe42ce5e685bcfa07c004cd95b92b297d33b71c3c': {'href': '', 'title': 'Ethereum Accoun'}, '0xef0d6e9d21609860df52e048ad32ab96145f39a6': {'href': '', 'title': 'Ethereum Accoun'}, '0x4ee4d86192e18fa8b1de0cd4c9b22bcde81d0576': {'href': '', 'title': 'Ethereum Accoun'}, '0x622a69180982c3469f0a9080724c194268ee9797': {'href': '', 'title': 'Ethereum Accoun'}, '0x85e871422b433027cc1e35065bf10c656cb11f4c': {'href': '', 'title': 'Ethereum BlockChain Explorer'}, '0x70f9ce5e838f40268d4f027498446877f63851ca': {'href': '', 'title': 'Ethereum BlockChain Explorer'}, '0x4324891c8b6ea7f4ebc7edde778dd65f3c2a03a1': {'href': '', 'title': 'Ethereum BlockChain Explorer'}, '0x7dd1c847e45c47dea82a7cfc5a3a04fc5af21e34': {'href': '', 'title': 'Ethereum BlockChain Explorer'}, '0x096d33d22f01b1caa34630af5b0b45ea02e894f9': {'href': '', 'title': 'Ethereum BlockChain Explorer'}, '0x7b3a23658f01e83de29971590f228ec4fc7c9700': {'href': '', 'title': 'Ethereum BlockChain Explorer'}, '0xaa198c58c8aa11c40f57473b14b7df67e7fc330c': {'href': '', 'title': 'Ethereum BlockChain Explorer'}, '0x39f6a6c85d39d5abad8a398310c52e7c374f2ba3': {'href': '', 'title': 'Ethereum BlockChain Explorer'}, '0x11b11301e1d47f457fb413dc7e48efb777b0fa28': {'href': '', 'title': 'Ethereum BlockChain Explorer'}, '0xfbb1b73c4f0bda4f67dca266ce6ef42f520fbb98': {'href': '', 'title': 'Ethereum BlockChain Explorer'}, '0xfc0dd985f6de9c2322ebd97c3422b0857c4d78c7': {'href': '', 'title': 'Ethereum BlockChain Explorer'}, '0xbb25a6e0b57ad738007d0160ceaf04c19ef38970': {'href': '', 'title': 'Ethereum BlockChain Explorer'}, '0x7758e507850da48cd47df1fb5f875c23e3340c50': {'href': '', 'title': 'Ethereum BlockChain Explorer'}, '0x376a46322c00c583e7fbe5881cee27fc218069c6': {'href': '', 'title': 'Ethereum BlockChain Explorer'}, '0xed279fdd11ca84beef15af5d39bb4d4bee23f0ca': {'href': '', 'title': 'Ethereum BlockChain Explorer'}}

# %%
clean_unweighted_owners = clean_address_owners(unweighted_address_owners)

# %%
count = 0
unweighted_top_scores = {}
for address in clean_unweighted_owners.keys():
    if(clean_unweighted_owners[address] != "unknown" and clean_unweighted_owners[address]!= "Ethereum BlockChain Explorer"):
        unweighted_top_scores[clean_unweighted_owners[address]] =
# Out:
# 0
# binance exchange
# 1
# SushiSwap OHMDAI 2 sushiswap
# 2
# coinbase
# 3
# Uniswap V2 DAI 2 uniswap
# 4
# SushiSwap USDT sushiswap
# 5
# blocked
# 6
# SushiSwap DAI sushiswap
# 7
# Wintermute
# 8
# BlockFi 3 blockfi
# 9
# POA Network xDAI Bridge poa-network bridge
# 10
# ClipperPool
# 11
# Uniswap V3 Router uniswap
# 12
# Uniswap V2 WHACKD 2 uniswap
# 13
# Polygon Matic ERC20 Bridge polygon-matic bridge
# 14
# Gemini 4 gemini
# 15
# Compound cDAI Token compound token-contract
# 16
# FlashWallet
# 17
# UniswapV2Pair
# 18
# SushiSwap USDC sushiswap
# 19
# ftx exchange
# 20
# GPv2Settlement
# 21
# SigThreePoolProxy
# 22
# Uniswap V3 DAI uniswap
# 23
# Curve Finance 3Pool curve-fi
# 24
# DXswapPair
# 25
# Ethswarm Bonding Curve
# 26
# UniswapV2Pair
# 27
# Vypercontract
# 28
# CroDefiSwapPair
# 29
# Uniswap V2 WBTCDAI 2 uniswap
# 30
# AaveZapV102
# 31
# Uniswap V2 DAIUBI uniswap
# 32
# Uniswap V3 DAI 2 uniswap
# 33
# Bridge
# 34
# Uniswap V2 DAIUSDT 2 uniswap
# 35
# L1Escrow
# 36
# ...
